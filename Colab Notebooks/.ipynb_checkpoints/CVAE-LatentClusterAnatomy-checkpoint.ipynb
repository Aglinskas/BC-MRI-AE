# %%
cd /mmfs1/data/aglinska/BC-MRI-AE/Colab Notebooks/

# %%
import pickle

import numpy as np
import pandas as pd 

from importlib import reload

import helper_funcs;reload(helper_funcs);from helper_funcs import *
import make_models;reload(make_models);from make_models import *

from functools import partial

# %%
dataFnOut = '/mmfs1/data/aglinska/BC-MRI-AE/Data/ABIDE-Anat-64iso-S982.npz'
dfFnOut = '/mmfs1/data/aglinska/BC-MRI-AE/Data/ABIDE_legend_S982.csv'

# %%
ABIDE_data = np.load(dataFnOut)['data']
df = pd.read_csv(dfFnOut)

# %%
patients = df['DxGroup'].values==1
controls = df['DxGroup'].values==2

# %%
batch_size = 32
asd_idx,td_idx = get_batch_idx(df,batch_size = batch_size)
DX_batch = np.take(ABIDE_data, indices=asd_idx, axis=0)
TD_batch = np.take(ABIDE_data, indices=td_idx, axis=0)

# %%
latent_dim=32;batch_size=64;disentangle=False;gamma=1
encoder, decoder, vae = get_MRI_VAE_3D(input_shape=(64, 64, 64, 1), latent_dim=latent_dim, batch_size=batch_size, disentangle=disentangle, gamma=gamma)
fn = '/mmfs1/data/aglinska/tf_outputs/VAE/Jan12th_16d'


loss = list()
print('ready')
if os.path.exists(fn+'_loss.pickle'):
    print('loading')
    vae.load_weights(fn)
    loss = pickle.load(open(fn+'_loss.pickle','rb'))
# Out:
# ready
# loading

# %%
latent_dim = 16
batch_size = 32;beta = 1;gamma = 100;disentangle = True
cvae, z_encoder, s_encoder, cvae_decoder = get_MRI_CCVAE_3D(latent_dim=latent_dim,beta=beta, disentangle=disentangle, gamma=gamma, bias=True, batch_size = batch_size)
loss = list()    

fdir = '/mmfs1/data/aglinska/tf_outputs/CVAE/'
#fn = f'{now().strftime("%b%d_%H%M")}_D{latent_dim}B{beta}G{gamma}_D{disentangle}'
fn = 'Feb04_0524_D16B1G100_DTrue'

fn = os.path.join(fdir,fn)

loss = pickle.load(open(fn+'_loss.pickle','rb'))
cvae.load_weights(fn)

# %%
im,im1,ss = cvae_query(ABIDE_data,s_encoder,z_encoder,cvae_decoder);
plot_trainProgress(loss,im,im1);

# %%
import helper_funcs;reload(helper_funcs);from helper_funcs import *

plot_trainProgress(loss,im,im1);
plot_four(DX_batch, TD_batch, z_encoder, s_encoder,cvae_decoder,cvae,idx=0)
plot_four(DX_batch, TD_batch, z_encoder, s_encoder,cvae_decoder,cvae,idx=1)
bg_space,sl_space = get_spaces(ABIDE_data, z_encoder, s_encoder, w=2)
cscatter([bg_space,sl_space],c=df['DxGroup'].values)

plt.figure(figsize=(5,5))
plot_sweep(ABIDE_data, z_encoder, s_encoder,cvae_decoder, wspace='z', l=5)
plt.show()

plt.figure(figsize=(5,5))
plot_sweep(ABIDE_data, z_encoder, s_encoder,cvae_decoder,wspace='s', l=5)
plt.show()

# %%
s = 5;k=30;ax='ax'
plot_four(DX_batch, TD_batch, z_encoder, s_encoder,cvae_decoder,cvae,idx=0,s=s,k=k,axis=ax)
plot_four(DX_batch, TD_batch, z_encoder, s_encoder,cvae_decoder,cvae,idx=1,s=s,k=k,axis=ax)

s = 5;k=30;ax='sag'
plot_four(DX_batch, TD_batch, z_encoder, s_encoder,cvae_decoder,cvae,idx=0,s=s,k=k,axis=ax)
plot_four(DX_batch, TD_batch, z_encoder, s_encoder,cvae_decoder,cvae,idx=1,s=s,k=k,axis=ax)

s = 5;k=30;ax='cor'
plot_four(DX_batch, TD_batch, z_encoder, s_encoder,cvae_decoder,cvae,idx=0,s=s,k=k,axis=ax)
plot_four(DX_batch, TD_batch, z_encoder, s_encoder,cvae_decoder,cvae,idx=1,s=s,k=k,axis=ax)

# %%
l = 2
plot_cvae_silhouettes(ABIDE_data,z_encoder,s_encoder,df,patients,keys=None,l=l)
plot_cvae_dif_mat(ABIDE_data,z_encoder,s_encoder,df,patients,l=l)
plot_cvae_dif_mat(ABIDE_data,z_encoder,s_encoder,df,controls,keys = ['AgeAtScan','ScannerID','ScanSiteID','FIQ','Sex'],l=l)

# %% [markdown]
# # SFARI DATA

# %%
arr = np.load('../Data/SFARI-Anat-64iso-S121.npz')
SFARI_data = arr['data']
SFARI_subs = arr['subs']
dfs = pd.read_csv('../Data/sfari_legend_S121.csv')

sfari_subs_td = dfs['family_type'].values=='non-familial-control'
sfari_subs_dupl = dfs['family_type'].values=='16p-duplication'
sfari_subs_del = dfs['family_type'].values=='16p-deletion'

sfari_td_batch = SFARI_data[sfari_subs_td,:,:,:][0:15,:,:,:]
sfari_dupl_batch = SFARI_data[sfari_subs_dupl,:,:,:][0:15,:,:,:]
sfari_del_batch = SFARI_data[sfari_subs_del,:,:,:][0:15,:,:,:]

# %%
s = 7;k=35;ax='sag'
plot_four(sfari_td_batch,sfari_td_batch,z_encoder, s_encoder,cvae_decoder,cvae,idx=0,s=s,k=k,axis=ax)
plot_four(sfari_td_batch,sfari_del_batch, z_encoder, s_encoder,cvae_decoder,cvae,idx=1,s=s,k=k,axis=ax)
plot_four(sfari_td_batch,sfari_dupl_batch, z_encoder, s_encoder,cvae_decoder,cvae,idx=1,s=s,k=k,axis=ax)

# %%
sfari_bg_space,sfari_sl_space = get_spaces(SFARI_data, z_encoder, s_encoder, w=2)

# %%
#dfs['ados_css'].values[dfs['ados_css'].values=='[]']=np.nan
#dfs['ados_css'] = pd.to_numeric(dfs['ados_css'],errors='coerce').values

# %%
# %%time
default_keys = ['best_full_scale_iq','ados_css','rrb_css','sa_css','ord_diagnosis','clinical_asd_dx','ord_scanner','age_months','ord_sex']
plt.figure(figsize=(15,15))
for i in range(len(default_keys)):
    ax = plt.subplot(4,4,i+1)
    rsa_results = [fit_rsa(dfs[default_keys[i]].values,SFARI_data,(sfari_subs_del+sfari_subs_dupl),[z_encoder,s_encoder,encoder]) for _ in range(10)]
    rsa_results = np.array(rsa_results)
    plot_rsa_results(rsa_results,ax=ax,title=default_keys[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in <listcomp>(.0)
#
# /mmfs1/data/aglinska/BC-MRI-AE/Colab Notebooks/helper_funcs.py in fit_rsa(inVec, ABIDE_data, g, encs, data_scale, metric)
#     440     # encs = [z_encoder,s_encoder,encoder]
#     441
# --> 442     v = g*~np.isnan(inVec)
#     443     vec_model = get_triu(make_RDM(inVec[v],data_scale=data_scale))
#     444
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
import helper_funcs;reload(helper_funcs);from helper_funcs import *
l = 2
keys = ['age_months','ord_sex','ord_gene','best_full_scale_iq','htwhc.head_circum_z_score','rrb_css','sa_css','ord_diagnosis','clinical_asd_dx','ord_scanner']
sub_vec = sfari_subs_td+sfari_subs_del+sfari_subs_dupl
plot_cvae_silhouettes(SFARI_data,z_encoder,s_encoder,dfs,sub_vec,keys=keys,l=l,w=2)
plot_cvae_dif_mat(SFARI_data,z_encoder,s_encoder,dfs,sub_vec,keys=keys,l=l)

# %%
bg_space,sl_space = get_spaces(ABIDE_data, z_encoder, s_encoder, w=2)

rdm_bg = 1-make_RDM(bg_space,data_scale='ratio')
rdm_sl = 1-make_RDM(sl_space,data_scale='ratio')

np.corrcoef(get_triu(rdm_bg),get_triu(rdm_sl))[0,1]
# Out:
# 0.000720780149006332

# %%
# rdm_bg = 1-make_RDM(z_encoder.predict(ABIDE_data)[2],data_scale='ratio')
# rdm_sl = 1-make_RDM(s_encoder.predict(ABIDE_data)[2],data_scale='ratio')

# %%
plt.figure(figsize=(15,5))
rdm_bg = 1-make_RDM(bg_space,data_scale='ratio')
rdm_sl = 1-make_RDM(sl_space,data_scale='ratio')
plt.subplot(1,2,1);
sns.heatmap(rdm_bg);
plt.title('BG.')

plt.subplot(1,2,2);
sns.heatmap(rdm_sl)
plt.title(f'SL. sl-bg corr: {np.corrcoef(get_triu(rdm_bg),get_triu(rdm_sl))[0,1]:.2f}');

# %%
# %%time
default_keys = ['ADOS_Total','ADOS_Social','DSMIVTR','AgeAtScan','Sex','ScannerID','ScanSiteID','FIQ']
scales_ = ['ratio','ratio','ordinal','ratio','ordinal','ordinal','ordinal','ratio']
plt.figure(figsize=(15,15))
#[plt.subplot(4,4,i+1) for i in range(8)];
for i in range(8):
    ax = plt.subplot(4,4,i+1)
    rsa_results = [fit_rsa(df[default_keys[i]].values,ABIDE_data,patients,[z_encoder,s_encoder,encoder],data_scale=scales_[i]) for _ in range(10)]
    rsa_results = np.array(rsa_results)
    plot_rsa_results(rsa_results,ax=ax,title=default_keys[i])

# %%
from matplotlib import pyplot as plt

# %%
# %%time
default_keys = ['ADOS_Total','ADOS_Social','DSMIVTR','ADI_R_SocialTotal','ADI_R_VerbalTotal','ADI_R_RRB','ADI_R_Onset Total','ADOS_Comm','ADOS_Social','ADOS_StBeh']
scales_ = ['ratio','ratio','ordinal','ratio','ratio','ratio','ratio','ratio',None,None,None,None,None,None,None]
plt.figure(figsize=(15,15))
#[plt.subplot(4,4,i+1) for i in range(8)];
for i in range(8):
    ax = plt.subplot(4,4,i+1)
    rsa_results = [fit_rsa(df[default_keys[i]].values,ABIDE_data,patients,[z_encoder,s_encoder,encoder],data_scale=scales_[i]) for _ in range(10)]
    rsa_results = np.array(rsa_results)
    plot_rsa_results(rsa_results,ax=ax,title=default_keys[i])

# %%
# %%time
default_keys = ['AgeAtScan','ScannerID','ScanSiteID','FIQ','Sex']
scales_ = ['ratio','ordinal','ordinal','ratio','ordinal']

plt.figure(figsize=(15,15))
for i in range(5):
    ax = plt.subplot(4,4,i+1)
    rsa_results = [fit_rsa(df[default_keys[i]].values,ABIDE_data,controls,[z_encoder,s_encoder,encoder],data_scale=scales_[i]) for _ in range(10)]
    rsa_results = np.array(rsa_results)
    plot_rsa_results(rsa_results,ax=ax,title=default_keys[i])

# %%
# dfs['best_full_scale_iq']=pd.to_numeric(dfs['best_full_scale_iq'],errors='coerce').values
# dfs['htwhc.bmi']=pd.to_numeric(dfs['htwhc.bmi'],errors='coerce').values
# dfs['htwhc.bmi_z_score']=pd.to_numeric(dfs['htwhc.bmi_z_score'],errors='coerce').values
# dfs['htwhc.head_circum_z_score']=pd.to_numeric(dfs['htwhc.head_circum_z_score'],errors='coerce').values
# dfs['rrb_css']=pd.to_numeric(dfs['rrb_css'],errors='coerce').values
# dfs['sa_css']=pd.to_numeric(dfs['sa_css'],errors='coerce').values
# dfs['clinical_asd_dx']=pd.to_numeric(dfs['clinical_asd_dx'],errors='coerce').values

# dfs['ord_diagnosis'] = str_to_ordinal(dfs['svip_diagnosis_m1'].values)
# dfs['ord_gene'] = str_to_ordinal(dfs['family_type'])
# dfs['ord_sex'] = str_to_ordinal(dfs['sex'].values)

# df_man = pd.read_csv('/mmfs1/data/aglinska/BC-ASD-FC/Excel/sfari_manufacturers.csv')
# idx = np.array([df_man['bids id'].values[s] in dfs['BIDS ID'].values for s in range(len(df_man))])
# df_man = df_man.iloc[idx]

# assert len(dfs)==len(df_man)
# assert all([dfs['BIDS ID'].values[s]==df_man['bids id'].values[s] for s in range(len(dfs))])

# man = df_man['man'].values
# dfs['scanner'] = man
# scannerID = str_to_ordinal(dfs['scanner'].values)
# scannerID[man=='unknown']=np.nan
# scannerID
# dfs['ord_scanner']=scannerID

# dfs.to_csv('/mmfs1/data/aglinska/BC-MRI-AE/Data/sfari_legend_121.csv')

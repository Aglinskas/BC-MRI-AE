# %% [markdown]
# Make sure the tf version is 2.5.0-dev20201111 or later (for model saving)

# %%
#!pip install tf-nightly -qqq --progress-bar off
import tensorflow as tf
print(tf.__version__)
#assert tf.__version__== '2.5.0-dev20201111','bad version'
# Out:
# 2.5.0-dev20201123

# %%
from datetime import datetime;now = datetime.now;t00 = now()
print(t00)
# Out:
# 2020-11-23 15:07:32.964836

# %%
pwd
# Out:
# '/gsfs0/data/aglinsai/BC-MRI-AE/Colab Notebooks'

# %%
# %matplotlib inline

import os
from matplotlib import pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd
from tqdm import tqdm

#from contrastive_vae.celeb_utils import get_celeb_vae
#from contrastive_vae.celeb_utils import get_celeb_cvae

import pandas as pd
from sklearn.metrics import silhouette_score

from mri_utils import get_MRI_CVAE_3D,get_MRI_CCVAE_3D

print(now()-t00)
# Out:
# 0:00:34.577685

# %%
cd ../
# Out:
# /gsfs0/data/aglinsai/BC-MRI-AE

# %% [markdown]
# SHAPE THE DATA

# %%
arr = np.load('./Data/ABIDE-Anat-64iso.npz')
ABIDE_data = arr['data']
ABIDE_subs = arr['subs']
nsubs = ABIDE_data.shape[0]
[arr.shape for arr in [ABIDE_subs,ABIDE_data]]
# Out:
# [(1022,), (1022, 64, 64, 64)]

# %%
aa = np.array([ABIDE_data[s,:,:,:].sum() for s in range(ABIDE_data.shape[0])])<5000
ABIDE_data = ABIDE_data[~aa,:,:,:]
ABIDE_subs = ABIDE_subs[~aa]
[arr.shape for arr in [ABIDE_subs,ABIDE_data]]
# Out:
# [(982,), (982, 64, 64, 64)]

# %%
df = pd.read_csv('./CSVs/ABIDE-legend.csv',header=0)
df = df.iloc[np.array([df['BIDS_ID'].values[s] in ABIDE_subs for s in range(len(df))])]
df.reset_index(inplace=True)

assert len(df)==len(ABIDE_subs),'dif lenghts'
assert all([df['BIDS_ID'][s]==ABIDE_subs[s] for s in range(len(df))]),'mismatch between df and goodsubs'

df.head(5)
# Out:
#    index  BIDS_ID Anonymized ID Subject Type      Visit  \
# 0      0  sub-001     A00033348      PATIENT  session_1
# 1      1  sub-002     A00033398      CONTROL  session_1
# 2      2  sub-003     A00033352      PATIENT  session_1
# 3      3  sub-004     A00033389      CONTROL  session_1
# 4      4  sub-005     A00033354      PATIENT  session_1
#
#    Days since enrollment  SubID  DxGroup DSMIVTR  AgeAtScan  ...  \
# 0                      8  51320        1       2       31.0  ...
# 1                      8  51373        2       0       46.0  ...
# 2                      8  51324        1       2       52.0  ...
# 3                      8  51364        2       0       26.0  ...
# 4                      8  51326        1       2       42.0  ...
#
#    WISC4 Pic Con Scaled  WISC4 Matrix Scaled  WISC4 Dig Span Scaled  \
# 0                   NaN                  NaN                    NaN
# 1                   NaN                  NaN                    NaN
# 2                   NaN                  NaN                    NaN
# 3                   NaN                  NaN                    NaN
# 4                   NaN                  NaN                    NaN
#
#    WISC4 Let Num Scaled WISC4 Coding Scaled WISC4 Sym Scaled Age at MPRAGE  \
# 0                   NaN                 NaN              NaN           NaN
# 1                   NaN                 NaN              NaN           NaN
# 2                   NaN                 NaN              NaN           NaN
# 3                   NaN                 NaN              NaN           NaN
# 4                   NaN                 NaN              NaN           NaN
#
#    Current Med Status  Medication Name  Off stimulants at EPI scan?
# 0                   0              NaN                          NaN
# 1                   0              NaN                          NaN
# 2                   0              NaN                          NaN
# 3                   0              NaN                          NaN
# 4                   0              NaN                          NaN
#
# [5 rows x 79 columns]

# %%
TD_subs = ABIDE_data[np.array(df['Subject Type']=='CONTROL'),:,:,:]
DX_subs = ABIDE_data[np.array(df['Subject Type']=='PATIENT'),:,:,:]

print(TD_subs.shape)
print(DX_subs.shape)
# Out:
# (500, 64, 64, 64)
# (456, 64, 64, 64)

# %%
dxArr = np.ones(len(df))
dxArr[np.array(df['Subject Type']=='PATIENT')]=2

# %% [markdown]
# TRAIN THE VAE

# %%
from scipy.spatial.distance import pdist
from scipy.spatial.distance import squareform

def plot_state_cvae():
    plt.figure(figsize=(12,5))
    plt.subplot(1,3,1)
    plt.imshow(vae.predict(TD_batch)[0,32,:,:,0])
    plt.subplot(1,3,2)
    plt.imshow(decoder.predict(np.random.randn(3,2))[0,32,:,:,0])
    plt.subplot(1,3,3)
    arr = encoder.predict(ABIDE_data)[2]
    plt.scatter(arr[:,0],arr[:,1],c=dxArr)

# %%
encoder, decoder, vae = get_MRI_CVAE_3D(input_shape=(64, 64, 64, 1), latent_dim=2, batch_size=32, disentangle=False, gamma=1)
#vae.load_weights('../tf_outputs/weights/lol')

# %%
plot_state_cvae()

# %% [markdown]
# # TRAIN THE CONTRASTIVE VAE

# %%
cvae, cvae_fg, z_encoder, z_encoder, cvae_decoder = get_MRI_CCVAE_3D()
#cvae.load_weights('../tf_outputs/3D_CCVAE_Weights/lol')

# %%
cvae_decoder.predict(np.random.randn(3,4))[0,32,:,:,0]
# Out:
# array([[0.5000228 , 0.4999285 , 0.5000527 , ..., 0.49996683, 0.50014794,
#         0.500074  ],
#        [0.4999722 , 0.50007445, 0.4998638 , ..., 0.49996796, 0.49988723,
#         0.4998808 ],
#        [0.4999597 , 0.5000029 , 0.5000031 , ..., 0.49991727, 0.5000979 ,
#         0.49998507],
#        ...,
#        [0.4998424 , 0.50009   , 0.5000285 , ..., 0.5003432 , 0.49987578,
#         0.49985003],
#        [0.5000454 , 0.500088  , 0.49999845, ..., 0.50003433, 0.5000759 ,
#         0.50022465],
#        [0.4999576 , 0.49996167, 0.4998583 , ..., 0.5000907 , 0.49984393,
#         0.5002037 ]], dtype=float32)

# %%
def plot_state_ccvae():
    plt.figure(figsize=(12,5))
    plt.subplot(1,3,1)
    plt.imshow(cvae.predict([TD_batch,TD_batch])[0][0,32,:,:,0])
    plt.subplot(1,3,2)
    plt.imshow(cvae_decoder.predict(np.random.randn(3,4))[0,32,:,:,0])
    plt.subplot(1,3,3)
    arr = z_encoder.predict(ABIDE_data)[2]
    plt.scatter(arr[:,0],arr[:,1],c=dxArr)

# %%
plot_state_ccvae()

# %%
t0 = now()
print(f'started: {now()}')
for i in range(2):
    e0 = now()
    hist = cvae.fit([DX_batch,TD_batch],epochs=1)
    cvae.save_weights('../tf_outputs/3D_CCVAE_Weights/lol')
    print(f"epoch time: {now()-e0}, elapsed time: {now()-t0}")
    
    if np.mod(i,25)==0:
        plot_state_ccvae()
        
print(f'done in: {now()-t0}')
# Out:
# 1/1 [==============================] - 21s 21s/step - loss: 118347.4531
# epoch time: 0:00:22.713717, elapsed time: 0:00:22.713998
# 1/1 [==============================] - 17s 17s/step - loss: 11383006387853328384.0000
# epoch time: 0:00:17.872046, elapsed time: 0:00:40.586223

# %%
# cvae.fit([DX_batch,TD_batch],epochs=1000)
# cvae.save_weights('../tf_outputs/3D_CCVAE_Weights/lol')

# %%
# cvae, cvae_fg, z_encoder, s_encoder, cvae_decoder = get_celeb_cvae(input_shape=(width, height, 3), latent_dim=latent_dim, bias=True, disentangle=True, gamma=1)

# for i in tqdm(range(10000)):
#   #DX_subs,TD_subs
#   #cvae.train_on_batch([DX_subs[np.random.randint(0,DX_subs.shape[0],batch_size),:,:,:],TD_subs[np.random.randint(0,TD_subs.shape[0],batch_size),:,:,:]])
#   cvae.train_on_batch([TD_subs[np.random.randint(0,TD_subs.shape[0],batch_size),:,:,:],DX_subs[np.random.randint(0,DX_subs.shape[0],batch_size),:,:,:]])

# %%
# plt.figure(figsize=(12,8))
# for i in range(4):
#   plt.subplot(1,4,i+1)
#   plt.imshow(ABIDE_data_3d[np.random.randint(1,high=ABIDE_data_3d.shape[0]),:,:,0])
#   plt.xticks([]);plt.yticks([])

# plt.figure(figsize=(12,8))
# for i in range(16):
#   plt.subplot(4,4,i+1)
#   plt.imshow(cvae_decoder.predict(np.random.randn(1,4))[0,:,:,0])
#   plt.xticks([]);plt.yticks([])

# %%
# plt.figure(figsize=(12,4))
# plt.subplot(1,3,1)
# z_mean, z_log_var, z = z_encoder(ABIDE_data_3d[:,:,:,:])
# x = z
# plt.scatter(x[:,0],x[:,1],c=dxArr)
# plt.title('background')

# plt.subplot(1,3,2)
# s_mean, s_log_var, s = s_encoder(ABIDE_data_3d[:,:,:,:])
# x = s
# plt.scatter(x[:,0],x[:,1],c=dxArr)
# plt.title('salient')

# plt.subplot(1,3,3)
# v_mean, v_log_var, v = encoder(ABIDE_data_3d[:,:,:,:])
# x = v
# plt.scatter(x[:,0],x[:,1],c=dxArr)
# plt.title('v')

# plt.figure(figsize=(6,4))
# plt.bar([0,1,2],[silhouette_score(z,dxArr),silhouette_score(s,dxArr),silhouette_score(v,dxArr)])
# plt.xticks([0,1,2],labels=['background','salient','vae'])

# %%
# from scipy.spatial.distance import pdist
# from scipy.spatial.distance import squareform

# arr = [ABIDE_data_3d[s,:,:,:].flatten() for s in range(ABIDE_data_3d.shape[0])]
# arr = np.array(arr)

# %%
# arrs = (np.corrcoef(arr),1-squareform(pdist(v)),1-squareform(pdist(z)),1-squareform(pdist(s)))
# ttls = ['anatomy','VAE','Background','Salient']
# plt.figure(figsize=(16,12))
# for i in range(4):
#   plt.subplot(2,2,i+1)
#   sns.heatmap(arrs[i])
#   plt.title(ttls[i])

# %%
# Get avg e dist between ASD and TD
# What is the 258 on the bottlenack

# %%
# s_encoder.summary()

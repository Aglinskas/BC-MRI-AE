# %%
from datetime import datetime;now = datetime.now;t00=now();

import os
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

# import torch
# import torch.nn as nn
# import torch.optim as optim

# %matplotlib inline
print(f'import done in {now()-t00}')
# Out:
# import done in 0:00:00.599409

# %%
from google.colab import drive
drive.mount("/content/drive")
print('done, mounted')
# Out:
# Mounted at /content/drive
# done, mounted

# %%
# !cd drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
os.chdir('./drive/My Drive/ImageNet')

# %%
pwd
# Out:
# '/content/drive/My Drive/ImageNet'

# %%
ls
# Out:
# decathlon-1.0-data-imagenet.tar

# %%
# !tar -xvf decathlon-1.0-data-imagenet.tar

# %%
# # importing OpenCV(cv2) module 
# import cv2 
# from google.colab.patches import cv2_imshow
# # Save image in set directory 
# # Read RGB image 
# img = cv2.imread('download-1.jpg')
# img = img / 255
# img = img + np.random.rand(201, 251, 3)*.25

# img = img * 255  
# # Output img with window name as 'image' 
# cv2_imshow(img)  
# cv2.imwrite(f'grass-{i:03}.jpg',img)

# %%
# Out:
# True

# %%
# Out:
# 'grass-002.jpg'

# %%
pwd
# Out:
# '/content/drive/My Drive/BC-MRI-AE/Data/Grass'

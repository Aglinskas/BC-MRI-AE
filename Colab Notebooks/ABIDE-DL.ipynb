# %%
from google.colab import drive
drive.mount("/content/drive")
print('done, mounted')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# done, mounted

# %%
cd /content/drive/My Drive/newData
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/newData'
# /content

# %%
def collect_and_download(derivative, pipeline, strategy, out_dir, less_than, greater_than, site, sex, diagnosis):
    """

    Function to collect and download images from the ABIDE preprocessed
    directory on FCP-INDI's S3 bucket

    Parameters
    ----------
    derivative : string
        derivative or measure of interest
    pipeline : string
        pipeline used to process data of interest
    strategy : string
        noise removal strategy used to process data of interest
    out_dir : string
        filepath to a local directory to save files to
    less_than : float
        upper age (years) threshold for participants of interest
    greater_than : float
        lower age (years) threshold for participants of interest
    site : string
        acquisition site of interest
    sex : string
        'M' or 'F' to indicate whether to download male or female data
    diagnosis : string
        'asd', 'tdc', or 'both' corresponding to the diagnosis of the
        participants for whom data should be downloaded

    Returns
    -------
    None
        this function does not return a value; it downloads data from
        S3 to a local directory

    :param derivative: 
    :param pipeline: 
    :param strategy: 
    :param out_dir: 
    :param less_than: 
    :param greater_than: 
    :param site: 
    :param sex:
    :param diagnosis:
    :return: 
    """

    # Import packages
    import os
    import urllib.request as request

    # Init variables
    mean_fd_thresh = 0.2
    s3_prefix = 'https://s3.amazonaws.com/fcp-indi/data/Projects/'\
                'ABIDE_Initiative'
    s3_pheno_path = '/'.join([s3_prefix, 'Phenotypic_V1_0b_preprocessed1.csv'])

    # Format input arguments to be lower case, if not already
    derivative = derivative.lower()
    pipeline = pipeline.lower()
    strategy = strategy.lower()

    # Check derivative for extension
    if 'roi' in derivative:
        extension = '.1D'
    else:
        extension = '.nii.gz'

    # If output path doesn't exist, create it
    if not os.path.exists(out_dir):
        print('Could not find {0}, creating now...'.format(out_dir))
        os.makedirs(out_dir)

    # Load the phenotype file from S3
    s3_pheno_file = request.urlopen(s3_pheno_path)
    pheno_list = s3_pheno_file.readlines()
    print(pheno_list[0])

    # Get header indices
    header = pheno_list[0].decode().split(',')
    try:
        site_idx = header.index('SITE_ID')
        file_idx = header.index('FILE_ID')
        age_idx = header.index('AGE_AT_SCAN')
        sex_idx = header.index('SEX')
        dx_idx = header.index('DX_GROUP')
        mean_fd_idx = header.index('func_mean_fd')
    except Exception as exc:
        err_msg = 'Unable to extract header information from the pheno file: {0}\nHeader should have pheno info:' \
                  ' {1}\nError: {2}'.format(s3_pheno_path, str(header), exc)
        raise Exception(err_msg)

    # Go through pheno file and build download paths
    print('Collecting images of interest...')
    s3_paths = []
    for pheno_row in pheno_list[1:]:

        # Comma separate the row
        cs_row = pheno_row.decode().split(',')

        try:
            # See if it was preprocessed
            row_file_id = cs_row[file_idx]
            # Read in participant info
            row_site = cs_row[site_idx]
            row_age = float(cs_row[age_idx])
            row_sex = cs_row[sex_idx]
            row_dx = cs_row[dx_idx]
            row_mean_fd = float(cs_row[mean_fd_idx])
        except Exception as e:
            err_msg = 'Error extracting info from phenotypic file, skipping...'
            print(err_msg)
            continue

        # If the filename isn't specified, skip
        if row_file_id == 'no_filename':
            continue
        # If mean fd is too large, skip
        if row_mean_fd >= mean_fd_thresh:
            continue

        # Test phenotypic criteria (three if's looks cleaner than one long if)
        # Test sex
        if (sex == 'M' and row_sex != '1') or (sex == 'F' and row_sex != '2'):
            continue

        if (diagnosis == 'asd' and row_dx != '1') or (diagnosis == 'tdc' and row_dx != '2'):
            continue

        # Test site
        if site is not None and site.lower() != row_site.lower():
            continue
        # Test age range
        if greater_than < row_age < less_than:
            filename = row_file_id + '_' + derivative + extension
            s3_path = '/'.join([s3_prefix, 'Outputs', pipeline, strategy, derivative, filename])
            print('Adding {0} to download queue...'.format(s3_path))
            s3_paths.append(s3_path)
        else:
            continue

    # And download the items
    total_num_files = len(s3_paths)
    for path_idx, s3_path in enumerate(s3_paths):
        rel_path = s3_path.lstrip(s3_prefix)
        download_file = os.path.join(out_dir, rel_path)
        download_dir = os.path.dirname(download_file)
        if not os.path.exists(download_dir):
            os.makedirs(download_dir)
        try:
            if not os.path.exists(download_file):
                print('Retrieving: {0}'.format(download_file))
                request.urlretrieve(s3_path, download_file)
                print('{0:3f}% percent complete'.format(100*(float(path_idx+1)/total_num_files)))
            else:
                print('File {0} already exists, skipping...'.format(download_file))
        except Exception as exc:
            print('There was a problem downloading {0}.\n Check input arguments and try again.'.format(s3_path))

    # Print all done
    print('Done!')

# %%
# Call the collect and download routine
desired_derivative = 'func_preproc'
desired_pipeline = 'cpac'
desired_strategy  = 'filt_global'
download_data_dir = '/content/drive/My Drive/ABIDE'
desired_age_max = 999
desired_age_min = -1
desired_site = None
desired_sex = None
desired_diagnosis = 'both'

collect_and_d ownload(desired_derivative, desired_pipeline, desired_strategy, download_data_dir, desired_age_max, desired_age_min, desired_site, desired_sex, desired_diagnosis)
# Out:
# b',Unnamed: 0,SUB_ID,X,subject,SITE_ID,FILE_ID,DX_GROUP,DSM_IV_TR,AGE_AT_SCAN,SEX,HANDEDNESS_CATEGORY,HANDEDNESS_SCORES,FIQ,VIQ,PIQ,FIQ_TEST_TYPE,VIQ_TEST_TYPE,PIQ_TEST_TYPE,ADI_R_SOCIAL_TOTAL_A,ADI_R_VERBAL_TOTAL_BV,ADI_RRB_TOTAL_C,ADI_R_ONSET_TOTAL_D,ADI_R_RSRCH_RELIABLE,ADOS_MODULE,ADOS_TOTAL,ADOS_COMM,ADOS_SOCIAL,ADOS_STEREO_BEHAV,ADOS_RSRCH_RELIABLE,ADOS_GOTHAM_SOCAFFECT,ADOS_GOTHAM_RRB,ADOS_GOTHAM_TOTAL,ADOS_GOTHAM_SEVERITY,SRS_VERSION,SRS_RAW_TOTAL,SRS_AWARENESS,SRS_COGNITION,SRS_COMMUNICATION,SRS_MOTIVATION,SRS_MANNERISMS,SCQ_TOTAL,AQ_TOTAL,COMORBIDITY,CURRENT_MED_STATUS,MEDICATION_NAME,OFF_STIMULANTS_AT_SCAN,VINELAND_RECEPTIVE_V_SCALED,VINELAND_EXPRESSIVE_V_SCALED,VINELAND_WRITTEN_V_SCALED,VINELAND_COMMUNICATION_STANDARD,VINELAND_PERSONAL_V_SCALED,VINELAND_DOMESTIC_V_SCALED,VINELAND_COMMUNITY_V_SCALED,VINELAND_DAILYLVNG_STANDARD,VINELAND_INTERPERSONAL_V_SCALED,VINELAND_PLAY_V_SCALED,VINELAND_COPING_V_SCALED,VINELAND_SOCIAL_STANDARD,VINELAND_SUM_SCORES,VINELAND_ABC_STANDARD,VINELAND_INFORMANT,WISC_IV_VCI,WISC_IV_PRI,WISC_IV_WMI,WISC_IV_PSI,WISC_IV_SIM_SCALED,WISC_IV_VOCAB_SCALED,WISC_IV_INFO_SCALED,WISC_IV_BLK_DSN_SCALED,WISC_IV_PIC_CON_SCALED,WISC_IV_MATRIX_SCALED,WISC_IV_DIGIT_SPAN_SCALED,WISC_IV_LET_NUM_SCALED,WISC_IV_CODING_SCALED,WISC_IV_SYM_SCALED,EYE_STATUS_AT_SCAN,AGE_AT_MPRAGE,BMI,anat_cnr,anat_efc,anat_fber,anat_fwhm,anat_qi1,anat_snr,func_efc,func_fber,func_fwhm,func_dvars,func_outlier,func_quality,func_mean_fd,func_num_fd,func_perc_fd,func_gsr,qc_rater_1,qc_notes_rater_1,qc_anat_rater_2,qc_anat_notes_rater_2,qc_func_rater_2,qc_func_notes_rater_2,qc_anat_rater_3,qc_anat_notes_rater_3,qc_func_rater_3,qc_func_notes_rater_3,SUB_IN_SMP\n'
# Collecting images of interest...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050004_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050005_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050006_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050007_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050008_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050009_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050010_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050011_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050012_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050014_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050015_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050016_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050020_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050022_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050023_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050024_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050025_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050027_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050029_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050030_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050031_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050032_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050033_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050034_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050035_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050036_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050037_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050038_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050040_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050041_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050042_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050044_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050045_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050046_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050047_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050048_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050050_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050051_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050052_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050055_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050056_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050057_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050058_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050059_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Pitt_0050060_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050102_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050104_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050105_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050107_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050111_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050112_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050113_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050114_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050115_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050116_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050117_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050118_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050119_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050121_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050122_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050125_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050127_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050128_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050129_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050130_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050131_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050132_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050133_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050134_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Olin_0050136_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050142_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050143_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050144_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050145_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050146_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050147_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050148_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050149_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050150_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050152_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050153_func_preproc.nii.gz to download queue...
# Error extracting info from phenotypic file, skipping...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050156_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050157_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050158_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050159_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050160_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050161_func_preproc.nii.gz to download queue...
# Error extracting info from phenotypic file, skipping...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050166_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050167_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050168_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050169_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050170_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/OHSU_0050171_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050182_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050183_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050184_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050186_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050187_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050188_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050189_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050190_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050191_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050193_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050194_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050195_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050196_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050197_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050198_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050199_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050200_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050201_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050203_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050204_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050205_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050206_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050207_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050208_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050209_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050210_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050211_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050212_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050213_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050214_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050215_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050216_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/SDSU_0050217_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050232_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050233_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050234_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050235_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050236_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050237_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050239_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050240_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050241_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050243_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050245_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050246_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050247_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050248_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050249_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050250_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050251_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050252_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050253_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050254_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050255_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050257_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050259_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050260_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050261_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050262_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050263_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050264_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050266_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050267_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050268_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050269_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050270_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/Trinity_0050271_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050272_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050273_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050274_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050275_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050276_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050277_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050278_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050280_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050282_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050283_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050284_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050285_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050287_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050289_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050290_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050291_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050292_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050293_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050294_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050295_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050297_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050298_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050300_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050301_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050302_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050307_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050310_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050314_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050315_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050318_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050319_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050320_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050321_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050324_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050325_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050326_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050327_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050329_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050330_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050331_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050332_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050334_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050335_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050336_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050337_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050338_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050339_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050340_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050341_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050342_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050343_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050344_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050345_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050346_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050347_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050348_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050349_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050350_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050351_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050352_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050353_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050355_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050356_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050357_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050358_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050360_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050361_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050362_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050363_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050364_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050365_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050366_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050367_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050368_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050369_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050370_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050372_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050373_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050374_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050375_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050377_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_1_0050379_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050382_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050385_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050386_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050387_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050388_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050390_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050391_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050397_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050399_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050402_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050404_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050405_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050406_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050407_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050408_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050410_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050411_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050412_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050413_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050414_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050415_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050416_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050417_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050418_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050419_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050421_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050424_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050425_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050426_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050427_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/UM_2_0050428_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/USM_0050433_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/USM_0050434_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/USM_0050435_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/USM_0050436_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/USM_0050437_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/USM_0050438_func_preproc.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/func_preproc/USM_0050439_func_preproc.nii.gz to download queue...
# ...
# 87.443439% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/UCLA_2_0051312_func_preproc.nii.gz
# 87.556561% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/UCLA_2_0051313_func_preproc.nii.gz
# 87.669683% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/UCLA_2_0051314_func_preproc.nii.gz
# 87.782805% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/UCLA_2_0051315_func_preproc.nii.gz
# 87.895928% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/UCLA_2_0051316_func_preproc.nii.gz
# 88.009050% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/UCLA_2_0051317_func_preproc.nii.gz
# 88.122172% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_a_0051318_func_preproc.nii.gz
# 88.235294% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_a_0051319_func_preproc.nii.gz
# 88.348416% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_a_0051321_func_preproc.nii.gz
# 88.461538% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_b_0051322_func_preproc.nii.gz
# 88.574661% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_b_0051323_func_preproc.nii.gz
# 88.687783% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_b_0051324_func_preproc.nii.gz
# 88.800905% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_b_0051325_func_preproc.nii.gz
# 88.914027% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_b_0051326_func_preproc.nii.gz
# 89.027149% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_b_0051327_func_preproc.nii.gz
# 89.140271% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051328_func_preproc.nii.gz
# 89.253394% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_d_0051329_func_preproc.nii.gz
# 89.366516% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_d_0051330_func_preproc.nii.gz
# 89.479638% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_d_0051331_func_preproc.nii.gz
# 89.592760% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051332_func_preproc.nii.gz
# 89.705882% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051333_func_preproc.nii.gz
# 89.819005% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051334_func_preproc.nii.gz
# 89.932127% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051335_func_preproc.nii.gz
# 90.045249% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051336_func_preproc.nii.gz
# 90.158371% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051338_func_preproc.nii.gz
# 90.271493% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051339_func_preproc.nii.gz
# 90.384615% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051340_func_preproc.nii.gz
# 90.497738% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051342_func_preproc.nii.gz
# 90.610860% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051343_func_preproc.nii.gz
# 90.723982% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051344_func_preproc.nii.gz
# 90.837104% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051345_func_preproc.nii.gz
# 90.950226% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051346_func_preproc.nii.gz
# 91.063348% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_c_0051347_func_preproc.nii.gz
# 91.176471% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_d_0051349_func_preproc.nii.gz
# 91.289593% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_d_0051351_func_preproc.nii.gz
# 91.402715% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_d_0051355_func_preproc.nii.gz
# 91.515837% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_d_0051356_func_preproc.nii.gz
# 91.628959% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_d_0051357_func_preproc.nii.gz
# 91.742081% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_d_0051360_func_preproc.nii.gz
# 91.855204% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_a_0051362_func_preproc.nii.gz
# 91.968326% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_a_0051363_func_preproc.nii.gz
# 92.081448% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_a_0051364_func_preproc.nii.gz
# 92.194570% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_a_0051365_func_preproc.nii.gz
# 92.307692% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_a_0051369_func_preproc.nii.gz
# 92.420814% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_a_0051370_func_preproc.nii.gz
# 92.533937% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_a_0051373_func_preproc.nii.gz
# 92.647059% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051456_func_preproc.nii.gz
# 92.760181% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051457_func_preproc.nii.gz
# 92.873303% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051458_func_preproc.nii.gz
# 92.986425% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051459_func_preproc.nii.gz
# 93.099548% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051460_func_preproc.nii.gz
# 93.212670% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051461_func_preproc.nii.gz
# 93.325792% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051462_func_preproc.nii.gz
# 93.438914% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051463_func_preproc.nii.gz
# 93.552036% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051464_func_preproc.nii.gz
# 93.665158% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051465_func_preproc.nii.gz
# 93.778281% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051466_func_preproc.nii.gz
# 93.891403% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051467_func_preproc.nii.gz
# 94.004525% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051468_func_preproc.nii.gz
# 94.117647% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051469_func_preproc.nii.gz
# 94.230769% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051470_func_preproc.nii.gz
# 94.343891% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051471_func_preproc.nii.gz
# 94.457014% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051472_func_preproc.nii.gz
# 94.570136% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051473_func_preproc.nii.gz
# 94.683258% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051474_func_preproc.nii.gz
# 94.796380% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051476_func_preproc.nii.gz
# 94.909502% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051477_func_preproc.nii.gz
# 95.022624% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051478_func_preproc.nii.gz
# 95.135747% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051479_func_preproc.nii.gz
# 95.248869% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051480_func_preproc.nii.gz
# 95.361991% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051481_func_preproc.nii.gz
# 95.475113% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051482_func_preproc.nii.gz
# 95.588235% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051483_func_preproc.nii.gz
# 95.701357% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051484_func_preproc.nii.gz
# 95.814480% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051485_func_preproc.nii.gz
# 95.927602% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051486_func_preproc.nii.gz
# 96.040724% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051487_func_preproc.nii.gz
# 96.153846% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051488_func_preproc.nii.gz
# 96.266968% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051489_func_preproc.nii.gz
# 96.380090% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051490_func_preproc.nii.gz
# 96.493213% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051491_func_preproc.nii.gz
# 96.606335% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051492_func_preproc.nii.gz
# 96.719457% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/Caltech_0051493_func_preproc.nii.gz
# 96.832579% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051557_func_preproc.nii.gz
# 96.945701% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051558_func_preproc.nii.gz
# 97.058824% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051559_func_preproc.nii.gz
# 97.171946% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051560_func_preproc.nii.gz
# 97.285068% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051561_func_preproc.nii.gz
# 97.398190% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051562_func_preproc.nii.gz
# 97.511312% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051563_func_preproc.nii.gz
# 97.624434% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051564_func_preproc.nii.gz
# 97.737557% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051565_func_preproc.nii.gz
# 97.850679% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051566_func_preproc.nii.gz
# 97.963801% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051567_func_preproc.nii.gz
# 98.076923% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051570_func_preproc.nii.gz
# 98.190045% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051571_func_preproc.nii.gz
# 98.303167% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051572_func_preproc.nii.gz
# 98.416290% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051573_func_preproc.nii.gz
# 98.529412% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051574_func_preproc.nii.gz
# 98.642534% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051576_func_preproc.nii.gz
# 98.755656% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051577_func_preproc.nii.gz
# 98.868778% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051578_func_preproc.nii.gz
# 98.981900% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051579_func_preproc.nii.gz
# 99.095023% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051580_func_preproc.nii.gz
# 99.208145% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051581_func_preproc.nii.gz
# 99.321267% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051582_func_preproc.nii.gz
# 99.434389% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051583_func_preproc.nii.gz
# 99.547511% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051584_func_preproc.nii.gz
# 99.660633% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/SBL_0051585_func_preproc.nii.gz
# 99.773756% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_a_0051606_func_preproc.nii.gz
# 99.886878% percent complete
# Retrieving: /content/drive/My Drive/ABIDE/Outputs/cpac/filt_global/func_preproc/MaxMun_a_0051607_func_preproc.nii.gz
# 100.000000% percent complete
# Done!

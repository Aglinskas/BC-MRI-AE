# %%
# !pip install boto3

# %%
from boto3.session import Session
import boto3

# %%
ACCESS_KEY = 'AKIAXO65CT57PTLDQALN'
SECRET_KEY = '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'

session = Session(aws_access_key_id=ACCESS_KEY,
              aws_secret_access_key=SECRET_KEY)

# %%
s3 = session.resource('s3')
your_bucket = s3.Bucket('hcp-openaccess')

# %%
file = your_bucket.objects.all()

# %%
s3 = boto3.client('s3',aws_access_key_id=ACCESS_KEY, aws_secret_access_key=SECRET_KEY)

# %%
buckets = s3.list_buckets()
buckets['Buckets']
# Out:
# [{'CreationDate': datetime.datetime(2018, 8, 13, 15, 10, 17, tzinfo=tzlocal()),
#   'Name': 'hcp-openaccess'},
#  {'CreationDate': datetime.datetime(2018, 7, 25, 21, 19, 33, tzinfo=tzlocal()),
#   'Name': 'hcp-openaccess-logfiles'},
#  {'CreationDate': datetime.datetime(2018, 4, 20, 15, 38, 14, tzinfo=tzlocal()),
#   'Name': 'hcp-openaccess-logs-temp'},
#  {'CreationDate': datetime.datetime(2018, 6, 8, 15, 51, 53, tzinfo=tzlocal()),
#   'Name': 'hcp-openaccess-logstorage-temp'},
#  {'CreationDate': datetime.datetime(2018, 6, 29, 13, 17, 2, tzinfo=tzlocal()),
#   'Name': 'hcp-openaccess-test'},
#  {'CreationDate': datetime.datetime(2018, 4, 20, 15, 43, 24, tzinfo=tzlocal()),
#   'Name': 'hcp-openaccess-trail-temp'}]

# %%
buckets['Buckets'][0]['Name']
# Out:
# 'hcp-openaccess'

# %%
#s3://hcp-openaccess/HCP_1200/100206/
#s3://hcp-openaccess/HCP_1200/100307/
#s3://hcp-openaccess/HCP_1200/100408/
#s3://hcp-openaccess/HCP_1200/100610/

# %%
s3r = boto3.resource('s3', aws_access_key_id=ACCESS_KEY,
    aws_secret_access_key=ACCESS_KEY)
bucket = s3r.Bucket('hcp-openaccess')

# %%
prefix = '/HCP_1200/100206/'
for object in bucket.objects.filter(Prefix = 'dirname'):
    if object.key == prefix:
        os.makedirs(os.path.dirname(object.key), exist_ok=True)
        continue;
    bucket.download_file(object.key, object.key)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-63-a179a0ab5cdc> in <module>()
#       1 prefix = '/HCP_1200/100206/'
# ----> 2 for object in bucket.objects.filter(Prefix = 'dirname'):
#       3     if object.key == prefix:
#       4         os.makedirs(os.path.dirname(object.key), exist_ok=True)
#       5         continue;
#
# /usr/local/lib/python3.6/dist-packages/boto3/resources/collection.py in __iter__(self)
#      81
#      82         count = 0
# ---> 83         for page in self.pages():
#      84             for item in page:
#      85                 yield item
#
# /usr/local/lib/python3.6/dist-packages/boto3/resources/collection.py in pages(self)
#     164         # we start processing and yielding individual items.
#     165         count = 0
# --> 166         for page in pages:
#     167             page_items = []
# ...

# %%
#s3://hcp-openaccess/HCP/100307/unprocessed/3T/rfMRI_REST2_RL/100307_3T_BIAS_32CH.nii.gz

# %%
your_bucket.objects.all()

# %%
s3.download_file('hcp-openaccess','HCP/100307/unprocessed/3T/rfMRI_REST2_RL/100307_3T_BIAS_32CH.nii.gz','1.nii')

# %%
with open('1.nii', 'wb') as f:
    s3.download_fileobj('BUCKET_NAME', 'OBJECT_NAME', f)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-55-58428e8714eb> in <module>()
#       1 with open('1.nii', 'wb') as f:
# ----> 2     s3.download_fileobj('BUCKET_NAME', 'OBJECT_NAME', f)
#
# /usr/local/lib/python3.6/dist-packages/boto3/s3/inject.py in download_fileobj(self, Bucket, Key, Fileobj, ExtraArgs, Callback, Config)
#     676             bucket=Bucket, key=Key, fileobj=Fileobj,
#     677             extra_args=ExtraArgs, subscribers=subscribers)
# --> 678         return future.result()
#     679
#     680
#
# /usr/local/lib/python3.6/dist-packages/s3transfer/futures.py in result(self)
#     104             # however if a KeyboardInterrupt is raised we want want to exit
#     105             # out of this and propogate the exception.
# --> 106             return self._coordinator.result()
#     107         except KeyboardInterrupt as e:
# ...

# %%
ls
# Out:
# 1.nii  sample_data/

# %%
# !du -sh "1.nii"
# Out:
# 784K	1.nii

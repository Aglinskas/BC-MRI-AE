# %%
# %matplotlib inline
# import os
# from matplotlib import pyplot as plt
# from datetime import datetime
# import numpy as np

# from datetime import datetime;now = datetime.now;t00=now();

# import torch
# import torch.nn as nn
# import torch.optim as optim

# import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/drive")
print('done, mounted')
# Out:
# Mounted at /content/drive
# done, mounted

# %%
cd /content/drive/My Drive/BC-MRI-AE/
# Out:
# /content/drive/My Drive/BC-MRI-AE

# %%
#!git init
# !git config --global user.email "aidas.aglinskas@gmail.com"
# !git config --global user.name 'Aglinskas'

# !git add -A
# !git commit -m 'add data Nov 6th'
# !git push https://aglinskas:Aidasa123@github.com/Aglinskas/BC-MRI-AE.git --force
# Out:
# [master 6d869c8] add data Nov 6th
#  118 files changed, 5117 insertions(+), 3 deletions(-)
#  create mode 100644 Colab Notebooks/Copy of MRI-CAE-MAIN.ipynb
#  rewrite Colab Notebooks/MRI-CAE-MAIN.ipynb (99%)
#  create mode 100644 Colab Notebooks/MRI-CCAE-MAIN.ipynb
#  rewrite Colab Notebooks/MRI-analyse-CAE-output.ipynb (88%)
#  rewrite Colab Notebooks/Other-DoGit.ipynb (99%)
#  create mode 100644 Colab Notebooks/Other-PLAY.ipynb
#  create mode 100644 Data/Grass/download-1.jpg
#  create mode 100644 Data/Grass/grass-001.jpg
#  create mode 100644 Data/Grass/grass-002.jpg
#  create mode 100644 Data/Grass/grass-003.jpg
#  create mode 100644 Data/Grass/grass-004.jpg
#  create mode 100644 Data/Grass/grass-005.jpg
#  create mode 100644 Data/Grass/grass-006.jpg
#  create mode 100644 Data/Grass/grass-007.jpg
#  create mode 100644 Data/Grass/grass-008.jpg
#  create mode 100644 Data/Grass/grass-009.jpg
#  create mode 100644 Data/Grass/grass-010.jpg
# ...

# %%
# !git filter-branch -f --index-filter 'git rm --cached --ignore-unmatch './models/5layer-256-batchNorme0_2020-11-03 16:53:14.450008
# Out:
# Rewrite 2208a37af0034f4491bf36d034055270b50ff1e9 (5/6) (1 seconds passed, remaining 0 predicted)    rm 'SFARI_DATA_for_CAE_64.npy'
# Rewrite 200c2c7bb7ff89b72197e40031302d25a3d02965 (5/6) (1 seconds passed, remaining 0 predicted)
# Ref 'refs/heads/master' was rewritten

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#!git commit -m 'first commit'
#!git remote add origin https://Aglinskas:Aidasa123@github.com/Aglinskas/BC-MRI-AE.git
#!git push -u origin master
#!git remote rm origin

# %%
# !git log 200c2c7bb7ff89b72197e40031302d25a3d02965
# Out:
# commit 200c2c7bb7ff89b72197e40031302d25a3d02965 (HEAD -> master)
# Author: Aglinskas <aidas.aglinskas@gmail.com>
# Date:   Mon Nov 2 19:15:40 2020 +0000
#
#     add data
#
# commit 2208a37af0034f4491bf36d034055270b50ff1e9
# Author: Aglinskas <aidas.aglinskas@gmail.com>
# Date:   Mon Nov 2 19:01:48 2020 +0000
#
#     add data
#
# commit 3116de8a0d24060cf21c1386db4605f7193129be
# Author: Aglinskas <aidas.aglinskas@gmail.com>
# Date:   Mon Nov 2 18:23:40 2020 +0000
#
#     check if this works
#
# commit 0d428f1dca79390a383159b559f8997ecaeaeccf
# Author: Aglinskas <aidas.aglinskas@gmail.com>
# Date:   Mon Nov 2 18:19:47 2020 +0000
#
#     new commit
#
# commit 48f4e4589d465d17da1b05932e3e8cfbf62d7dcb
# Author: Aglinskas <aidas.aglinskas@gmail.com>
# Date:   Mon Nov 2 17:58:35 2020 +0000
#
#     first commit
#
# commit 247d879878909e99614d4777fa43341d35ebbdc5
# Author: Aglinskas <aidas.aglinskas@gmail.com>
# Date:   Mon Nov 2 17:53:01 2020 +0000
#
#     first commit

# %%
# Out:
# commit 200c2c7bb7ff89b72197e40031302d25a3d02965 (HEAD -> master)
# Author: Aglinskas <aidas.aglinskas@gmail.com>
# Date:   Mon Nov 2 19:15:40 2020 +0000
#
#     add data
#
# commit 2208a37af0034f4491bf36d034055270b50ff1e9
# Author: Aglinskas <aidas.aglinskas@gmail.com>
# Date:   Mon Nov 2 19:01:48 2020 +0000
#
#     add data
#
# commit 3116de8a0d24060cf21c1386db4605f7193129be
# Author: Aglinskas <aidas.aglinskas@gmail.com>
# Date:   Mon Nov 2 18:23:40 2020 +0000
#
#     check if this works
#
# commit 0d428f1dca79390a383159b559f8997ecaeaeccf
# Author: Aglinskas <aidas.aglinskas@gmail.com>
# Date:   Mon Nov 2 18:19:47 2020 +0000
#
#     new commit
#
# commit 48f4e4589d465d17da1b05932e3e8cfbf62d7dcb
# Author: Aglinskas <aidas.aglinskas@gmail.com>
# Date:   Mon Nov 2 17:58:35 2020 +0000
#
#     first commit
#
# commit 247d879878909e99614d4777fa43341d35ebbdc5
# Author: Aglinskas <aidas.aglinskas@gmail.com>
# Date:   Mon Nov 2 17:53:01 2020 +0000
#
#     first commit

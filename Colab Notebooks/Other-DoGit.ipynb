# %%
# %matplotlib inline
import os
from matplotlib import pyplot as plt
from datetime import datetime
import numpy as np

from datetime import datetime;now = datetime.now;t00=now();

import torch
import torch.nn as nn
import torch.optim as optim

import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/drive")
print('done, mounted')
# Out:
# Mounted at /content/drive
# done, mounted

# %%
cd /content/drive/My Drive/BC-MRI-AE/
# Out:
# /content/drive/My Drive/BC-MRI-AE

# %%
# !git add -A
# !git commit -m 'check if this works'
# !git push https://aglinskas:Aidasa123@github.com/Aglinskas/BC-MRI-AE.git
# Out:
#  abide_good_subs.npy   data2.npy      DS-use.csv   SFARI_DATA_for_CAE_64.npy
#  ABIDE-legend.csv      data.npy       models/      SFARI-legend.csv
# 'Colab Notebooks'/     data.npy.zip   NewCSV.csv   sfari_subs.npy

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/BC-MRI-AE/.git/

# %%
# !git config --global user.email "aidas.aglinskas@gmail.com"
# !git config --global user.name 'Aglinskas'

# %%
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 1.19 KiB | 406.00 KiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/Aglinskas/BC-MRI-AE.git
#    48f4e45..0d428f1  master -> master

# %%
# !git commit -m 'first commit'
# Out:
# [master 48f4e45] first commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Colab Notebooks/Other-DoGit.ipynb (68%)

# %%
# !git remote add origin https://Aglinskas:Aidasa123@github.com/Aglinskas/BC-MRI-AE.git
# Out:
# fatal: remote origin already exists.

# %%
# !git push -u origin master
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://Aglinskas:f6cfd542c4a90ef7976e74a13cd16c647ea34492@github.com/Aglinskas/BC-MRI-AE.git/'

# %%
# !git remote rm origin

# %%
ls
# Out:
#  abide_good_subs.npy   CSVs/        models/   sfari_subs.npy
# 'Colab Notebooks'/     DS-use.csv   NEW.csv

# %%
# !cat config
#!cd .git
# Out:
# cat: config: No such file or directory

# %%
from google.colab import drive
drive.mount("/content/drive")
print('done, mounted')
print(now())
# Out:
# Mounted at /content/drive
# done, mounted
# 2020-11-02 10:17:12.067990

# %%
#data = np.random.rand(131,160,64,64)
#data = np.load('/content/drive/My Drive/abide_data_60.npy')
data = np.load('/content/drive/My Drive/abide_data_60iso_1060.npy')

for s in range(data.shape[0]):
  data[s,:,:,:] = (data[s,:,:,:]-data[s,:,:,:].min()) / (data[s,:,:,:].max()-data[s,:,:,:].min())
  
print(data.shape)
# Out:
# (1060, 1, 64, 64, 64)

# %%
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# 1
# Tesla P4

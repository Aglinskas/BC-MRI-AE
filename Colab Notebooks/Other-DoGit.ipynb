# %%
# %matplotlib inline
import os
from matplotlib import pyplot as plt
from datetime import datetime
import numpy as np

from datetime import datetime;now = datetime.now;t00=now();

import torch
import torch.nn as nn
import torch.optim as optim

import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/drive")
print('done, mounted')
# Out:
# Mounted at /content/drive
# done, mounted

# %%
cd /content/drive/My Drive/BC-MRI-AE/
# Out:
# /content/drive/My Drive/BC-MRI-AE

# %%
ls
# Out:
#  abide_good_subs.npy   data2.npy      DS-use.csv   SFARI_DATA_for_CAE_64.npy
#  ABIDE-legend.csv      data.npy       models/      SFARI-legend.csv
# 'Colab Notebooks'/     data.npy.zip   NewCSV.csv   sfari_subs.npy

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/BC-MRI-AE/.git/

# %%
# !git config --global user.email "aidas.aglinskas@gmail.com"
# !git config --global user.name 'Aglinskas'

# %%
# !git add -A

# %%
# !git commit -m 'first commit'
# Out:
# [master (root-commit) 247d879] first commit
#  34 files changed, 2480 insertions(+)
#  create mode 100644 ABIDE-legend.csv
#  create mode 100644 Colab Notebooks/ABIDE-DL.ipynb
#  create mode 100644 Colab Notebooks/ABIDE-GetInShape.ipynb
#  create mode 100644 Colab Notebooks/Copy of MRI-CAE-SGD.ipynb
#  create mode 100644 Colab Notebooks/HCP-AcessData.ipynb
#  create mode 100644 Colab Notebooks/IBP-Binary.ipynb
#  create mode 100644 Colab Notebooks/IBP-Graded.ipynb
#  create mode 100644 Colab Notebooks/IBP-Graded_IPB_recoversFactors.ipynb
#  create mode 100644 Colab Notebooks/MRI-CAE-MAIN.ipynb
#  create mode 100644 Colab Notebooks/MRI-CAE-NoLinear-Fourier.ipynb
#  create mode 100644 Colab Notebooks/MRI-CAE-NoLinear.ipynb
#  create mode 100644 Colab Notebooks/MRI-analyse-CAE-output.ipynb
#  create mode 100644 Colab Notebooks/NIH-R21-ExtractData-fMRI-CAE.ipynb
#  create mode 100644 Colab Notebooks/Other-DoGit.ipynb
#  create mode 100644 Colab Notebooks/fMRI-CAE-NoLinear.ipynb
#  create mode 100644 DS-use.csv
#  create mode 100644 NewCSV.csv
#  create mode 100644 SFARI-legend.csv
#  create mode 100644 abide_good_subs.npy
#  create mode 100644 models/5layer-128-batchNorme0_2020-10-30 17:42:37.536677
#  create mode 100644 models/5layer-128-batchNorme0_2020-10-30 18:05:44.127459
#  create mode 100644 models/5layer-128-batchNorme100_2020-10-30 17:51:55.266085
#  create mode 100644 models/5layer-128-batchNorme200_2020-10-30 18:01:00.232374
#  create mode 100644 models/5layer-128-batchNorme300_2020-10-30 18:10:17.562500
#  create mode 100644 models/5layer-128-batchNorme400_2020-10-30 18:19:18.357816
#  create mode 100644 models/5layer-128-batchNorme500_2020-10-30 18:28:12.677077
#  create mode 100644 models/5layer-256-batchNorme0_2020-10-30 18:52:15.625901
#  create mode 100644 models/5layer-256-batchNorme0_2020-10-30 18:53:18.397344
#  create mode 100644 models/5layer-256-batchNorme100_2020-10-30 19:02:06.470759
#  create mode 100644 models/5layer-256-batchNorme200_2020-10-30 19:10:55.199313
#  create mode 100644 models/5layer-256-batchNorme300_2020-10-30 19:19:43.830076
#  create mode 100644 models/5layer-256-batchNorme400_2020-10-30 19:28:31.226767
#  create mode 100644 models/5layer-256-batchNorme500_2020-10-30 19:37:20.298982
#  create mode 100644 sfari_subs.npy

# %%
# !git remote add origin https://Aglinskas:f6cfd542c4a90ef7976e74a13cd16c647ea34492github@github.com/Aglinskas/BC-MRI-AE.git
# Out:
# fatal: remote origin already exists.

# %%
# !git push -u origin master
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://Aglinskas:f6cfd542c4a90ef7976e74a13cd16c647ea34492github@github.com/Aglinskas/BC-MRI-AE.git/'

# %%
# !git remote rm origin

# %%
# !cat config
#!cd .git
# Out:
# [core]
# 	repositoryformatversion = 0
# 	filemode = true
# 	bare = false
# 	logallrefupdates = true
# [remote "origin"]
# 	url = https://github.com/Aglinskas/BC-BNP.git
# 	fetch = +refs/heads/*:refs/remotes/origin/*
# [branch "master"]
# 	remote = origin
# 	merge = refs/heads/master

# %%
from google.colab import drive
drive.mount("/content/drive")
print('done, mounted')
print(now())
# Out:
# Mounted at /content/drive
# done, mounted
# 2020-11-02 10:17:12.067990

# %%
#data = np.random.rand(131,160,64,64)
#data = np.load('/content/drive/My Drive/abide_data_60.npy')
data = np.load('/content/drive/My Drive/abide_data_60iso_1060.npy')

for s in range(data.shape[0]):
  data[s,:,:,:] = (data[s,:,:,:]-data[s,:,:,:].min()) / (data[s,:,:,:].max()-data[s,:,:,:].min())
  
print(data.shape)
# Out:
# (1060, 1, 64, 64, 64)

# %%
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# 1
# Tesla P4

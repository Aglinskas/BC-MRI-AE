# %%
import ants
import numpy as np

# %%
fn = '/Volumes/Samsung_T5/DS-use-new-atlas/sub-004/func/rrsub-004_task-lang_run-1_bold.nii'

# %%
im4d = ants.image_read(fn)
im3d = ants.slice_image(im4d,axis=3,idx=0)

# %%
nt = im4d.shape[-1]
s = im4d.shape

# %%
im3d.plot(nslices=5)

# %%
arr = im4d.numpy()
mat = arr.reshape(-1,nt)

# %%
#from sklearn.decomposition import FastICA

# %%
ica = FastICA(n_components=25,random_state=0)
comp = ica.fit_transform(mat)

# %%
from matplotlib import pyplot as plt

# %%
ncomp = comp.shape[1]
comp = comp.reshape(72, 72, 49,ncomp)

# %%
for i in range(ncomp):
    ica_comp = comp[:,:,:,i]
    ov = im3d.new_image_like(norm(ica_comp))
    ov[ov<.1]=0
    im3d.plot(overlay=ov,overlay_alpha=.3,slices=[25,30,35])

# %%
def norm(arr):
    arr = (arr - arr.min()) / (arr.max()-arr.min())
    return arr

# %%
# Out:
# 0.0
